# %% [markdown]
# # 데이터분석 소개

# %% [markdown]
# ## 1장

# %% [markdown]
# `numpy` 라이브러리 불러오기

# %%
import numpy as np

# %%
np.random.seed(42)
np.random.rand(5)
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848, 0.15601864])
